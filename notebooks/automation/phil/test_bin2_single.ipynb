# %% [markdown]
# # Show4DSTEM - bin 2, single dataset (MacBook MPS)
#
# Detector binned 2x at load. Data is already small, so the virtual image is fast directly - no sidecar is built (det_bin>=2 needs none).

# %%
from quantem.widget import load, Show4DSTEM

master = "/Users/macbook/data/sample/Sample_3.6Mx_21.4mrad_185mmcl_20pA_01_master.h5"
Show4DSTEM(load(master, det_bin=2))
