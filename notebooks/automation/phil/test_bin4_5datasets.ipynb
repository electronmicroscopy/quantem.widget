# %% [markdown]
# # Show4DSTEM - bin 4, five datasets (MacBook MPS, lazy)
#
# Five acquisitions binned 4x. Dataset 0 shows in ~2s; datasets 1..4 decode in a background thread and the Dataset slider grows as each lands. Lazy hides the time, not the footprint.

# %%
from quantem.widget import load, Show4DSTEM

masters = [
    "/Users/macbook/data/sample/Sample_3.6Mx_21.4mrad_185mmcl_20pA_01_master.h5",
    "/Users/macbook/data/sample/Sample_3.6Mx_21.4mrad_185mmcl_20pA_03_master.h5",
    "/Users/macbook/data/sample/Sample_3.6Mx_21.4mrad_185mmcl_20pA_11_master.h5",
    "/Users/macbook/data/sample/Sample_3.6Mx_21.4mrad_185mmcl_20pA_29_master.h5",
    "/Users/macbook/data/sample/Sample_3.6Mx_21.4mrad_185mmcl_20pA_30_master.h5",
]
Show4DSTEM(load(masters, det_bin=4))
