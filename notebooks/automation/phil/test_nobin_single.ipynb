# %% [markdown]
# # Show4DSTEM - no bin, single dataset (MacBook MPS, sidecar)
#
# Full 192x192 detector kept in unified Metal memory for full-resolution CBED. The virtual image auto-builds a bin2 sidecar in the background so BF/DF/ADF stay real-time (4x less data to read). Drag the detector ROI - the virtual image follows live.

# %%
from quantem.widget import load, Show4DSTEM

master = "/Users/macbook/data/sample/Sample_3.6Mx_21.4mrad_185mmcl_20pA_01_master.h5"
Show4DSTEM(load(master, det_bin=1))
