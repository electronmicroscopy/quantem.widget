# %% [markdown]
# # Show4DSTEM - bin 4, five datasets (Linux CUDA)
#
# Five acquisitions binned 4x, eager-stacked into one 5D array. The Dataset slider switches between them instantly (big VRAM, no lazy fill needed).

# %%
from quantem.widget import load, Show4DSTEM

masters = [
    "/data/sample/series/Sample_3.6Mx_21.4mrad_185mmcl_20pA_01_master.h5",
    "/data/sample/series/Sample_3.6Mx_21.4mrad_185mmcl_20pA_03_master.h5",
    "/data/sample/series/Sample_3.6Mx_21.4mrad_185mmcl_20pA_11_master.h5",
    "/data/sample/series/Sample_3.6Mx_21.4mrad_185mmcl_20pA_29_master.h5",
    "/data/sample/series/Sample_3.6Mx_21.4mrad_185mmcl_20pA_30_master.h5",
]
Show4DSTEM(load(masters, det_bin=4))
