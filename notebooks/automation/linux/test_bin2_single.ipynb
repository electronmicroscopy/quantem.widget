# %% [markdown]
# # Show4DSTEM - bin 2, single dataset (Linux CUDA)
#
# Detector binned 2x (96x96) at load. Quarter the VRAM, fast virtual image, slightly coarser CBED.

# %%
from quantem.widget import load, Show4DSTEM

master = "/data/sample/series/Sample_3.6Mx_21.4mrad_185mmcl_20pA_01_master.h5"
Show4DSTEM(load(master, det_bin=2))
