# %% [markdown]
# # Show4DSTEM - no bin, single dataset (Linux CUDA)
#
# Full 192x192 detector, one acquisition. CUDA holds the whole no-bin stack in VRAM; the virtual image is computed directly (no sidecar - that is the MacBook path).

# %%
from quantem.widget import load, Show4DSTEM

master = "/data/sample/series/Sample_3.6Mx_21.4mrad_185mmcl_20pA_01_master.h5"
Show4DSTEM(load(master, det_bin=1))
