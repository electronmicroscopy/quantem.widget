# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %% [markdown]
# # IO.folder
#
# Read all files in a folder as a stack with `IO.folder(path)`. Supports `file_type` filter and `recursive` flag.

# %%
from quantem.widget import IO, Show3D

# %% [markdown]
# ## PNG folder

# %%
result = IO.folder("/Users/macbook/data/collaboratorC/20260221_show3d/", file_type="png")
print(result)
Show3D(result, title="Te/ReSe2 Growth Series")
# Out:
# IOResult
#   shape:      3 x 2048 x 2048
#   dtype:      float32
#   memory:     48 MB
#   title:      20260221_show3d
#   labels:     ['20250311T151608.976Raw1', '20250311T151702.418Raw10', '20250311T151802.003Raw20']
# Show3D(3×2048×2048, frame=1, cmap=magma)

# %% [markdown]
# ## TIFF folder

# %%
result = IO.folder("/Users/macbook/data/20251216_Korea_Sample_C1/", file_type="tif")
print(result)
Show3D(result, title="Korean Sample Virtual Images")
# Out:
# IOResult
#   shape:      40 x 256 x 256
#   dtype:      float32
#   memory:     10 MB
#   title:      20251216_Korea_Sample_C1
#   labels:     ['KoreanSampleC1Bob_00_Virtual00_8bit', 'KoreanSampleC1Bob_00_Virtual05_8bit', 'KoreanSampleC1Bob_00_Virtual10_8bit', ...] (40 total)
# Show3D(40×256×256, frame=20, cmap=magma)

# %% [markdown]
# ## EMD folder

# %%
result = IO.folder("/Users/macbook/data/will/", file_type="emd")
print(result)
Show3D(result, title="STEM HAADF Series")
# Out:
# IOResult
#   shape:      6 x 2048 x 2048
#   dtype:      float32
#   memory:     96 MB
#   title:      will
#   pixel_size: 0.0930 Å
#   labels:     ['HAADF', 'HAADF', 'HAADF', ...] (6 total)
#   metadata:   2 fields
# Show3D(6×2048×2048, frame=3, cmap=magma)

# %% [markdown]
# ## DM3 folder

# %%
result = IO.folder(
    "/Users/macbook/data/20251209_KoreanSample/C1_TEM_Bob/Bob_Lee_Sangjoon/",
    file_type="dm3",
)
print(result)
Show3D(result, title="Co3O4 TEM Series")
# Out:
# IOResult
#   shape:      5 x 4096 x 4096
#   dtype:      float32
#   memory:     320 MB
#   title:      Bob_Lee_Sangjoon
#   pixel_size: 0.1711 Å
#   labels:     ['final_0001', 'final_0002', 'final_0003', ...] (5 total)
#   metadata:   2 fields
# Show3D(5×4096×4096, frame=2, cmap=magma)

# %% [markdown]
# ## Recursive folder

# %%
result = IO.folder(
    "/Users/macbook/data/20251209_KoreanSample/C1_TEM_Bob/Bob_Lee_Sangjoon/",
    file_type="dm3",
    recursive=True,
)
print(result)
# Out:
# IOResult
#   shape:      8 x 4096 x 4096
#   dtype:      float32
#   memory:     512 MB
#   title:      Bob_Lee_Sangjoon
#   pixel_size: 0.1711 Å
#   labels:     ['korea_c1_Co3O4_TEM_0001', 'korea_c1_Co3O4_TEM_0002', 'korea_c1_Co3O4_TEM_0003', ...] (8 total)
#   metadata:   2 fields
