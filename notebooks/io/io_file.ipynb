# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %% [markdown]
# # IO.file
#
# Read any single file with `IO.file(path)`. Returns an `IOResult` with `data`, `pixel_size`, `units`, `title` — pass directly to any widget.

# %%
from quantem.widget import IO, Show2D, Show3D

# %% [markdown]
# ## DM4

# %%
result = IO.file("/Users/macbook/data/guoliang/widget_demo/gold20nm_RRjacobsens_0018.dm4")
print(result)
# Out:
# IOResult
#   shape:      1024 x 1024
#   dtype:      float32
#   memory:     4 MB
#   title:      gold20nm_RRjacobsens_0018
#   pixel_size: 1.4298 Å
#   metadata:   2 fields

# %%
Show2D(result, show_fft=True, log_scale=True)
# Out:
# Show2D(1024×1024, cmap=inferno)

# %% [markdown]
# ## EMD (Velox)

# %%
result = IO.file("/Users/macbook/data/will/0070 - VWS2_9h_g_300kv STEM HAADF 5.20 Mx Diffraction.emd")
print(result)
Show2D(result, show_fft=True)
# Out:
# IOResult
#   shape:      2048 x 2048
#   dtype:      float32
#   memory:     16 MB
#   title:      HAADF
#   pixel_size: 0.0930 Å
#   metadata:   2 fields
# Show2D(2048×2048, cmap=inferno)

# %% [markdown]
# ## PNG

# %%
result = IO.file("/Users/macbook/data/collaboratorC/20260221_show3d/20250311T151608.976Raw1.png")
print(result)
Show2D(result)
# Out:
# IOResult
#   shape:      2048 x 2048
#   dtype:      float32
#   memory:     16 MB
#   title:      20250311T151608.976Raw1
# Show2D(2048×2048, cmap=inferno)

# %% [markdown]
# ## TIFF

# %%
result = IO.file("/Users/macbook/data/jiwoo/0827_PdAu3wo focal/FocalSeries_0001/16bit_FocalSeries_0001_03_cropped.tif")
print(result)
Show2D(result)
# Out:
# IOResult
#   shape:      2049 x 2040
#   dtype:      float32
#   memory:     16 MB
#   title:      16bit_FocalSeries_0001_03_cropped
#   labels:     ['16bit_FocalSeries_0001_03_cropped[0]']
# Show2D(2049×2040, cmap=inferno)

# %% [markdown]
# ## NPY

# %%
result = IO.file("/Users/macbook/data/collaboratorC/te_growth_high_mag_Te_ReSe2_18_f_1.npy")
print(result)
Show2D(result)
# Out:
# IOResult
#   shape:      1024 x 1024
#   dtype:      float32
#   memory:     4 MB
#   title:      te_growth_high_mag_Te_ReSe2_18_f_1
# Show2D(1024×1024, cmap=inferno)

# %% [markdown]
# ## Supported formats

# %%
IO.supported_formats()
# Out:
# ['ali',
#  'app5',
#  'asw',
#  'bcf',
#  'blo',
#  'bmp',
#  'csv',
#  'de5',
#  'dens',
#  'dib',
#  'dm3',
#  'dm4',
#  'eds',
#  'elid',
#  'emd',
#  'emi',
#  'ems',
#  'emsa',
#  'gif',
#  'h5',
#  'hdf5',
#  'hspy',
#  'img',
#  'jpe',
#  'jpeg',
#  'jpg',
#  'map',
#  'mas',
#  'mib',
#  'mrc',
#  'mrcz',
#  'msa',
#  'msp',
#  'nc',
#  'npy',
#  'npz',
#  'nxs',
#  'pbm',
#  'pcx',
#  'pgm',
#  'png',
#  'ppm',
#  'pro',
#  'prz',
#  'pts',
#  'rpl',
#  'ser',
#  'spc',
#  'spd',
#  'spi',
#  'spx',
#  'sur',
#  'tif',
#  'tiff',
#  'tvf',
#  'tvips',
#  'unf',
#  'wdf',
#  'xbm',
#  'xml',
#  'zspy']
